# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install lxml
# Out:
# ...
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------- ----------------------------- 1.0/4.0 MB 25.4 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 24.2 MB/s  0:00:00
# ...

# %%
df = pd.read_xml("basic_xml.xml")
df
# Out:
#    name  age      city
# 0  John   30  New York
# 1  Anna   25     Paris

# %%
d_complex = pd.read_xml("complex_xml_structures.xml")
d_complex
# Out:
#   name      city
# 0  USA  \n

# %% [markdown]
# city showing \n. so, going inside it

# %%
d_complex = pd.read_xml("complex_xml_structures.xml", xpath= ".//city")
d_complex
# Out:
#        name  person
# 0  New York     NaN

# %%
namespaces = {"ns" : "https://www.example.com"}
dataframe = pd.read_xml("/content/xml_namespace.xml", namespaces=namespaces)
dataframe
# Out:
#   name      city
# 0  USA  \n
